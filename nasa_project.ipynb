# %%
import pandas as pd

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import requests

url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-07&api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ"

response = requests.get(url)

response
# Out:
# <Response [200]>

# %%
data=response.json()
data
# Out:
# {'links': {'next': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-07&end_date=2024-01-13&detailed=false&api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ',
#   'previous': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2023-12-26&end_date=2024-01-01&detailed=false&api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ',
#   'self': 'http://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-07&detailed=false&api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ'},
#  'element_count': 106,
#  'near_earth_objects': {'2024-01-02': [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2415949?api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ'},
#     'id': '2415949',
#     'neo_reference_id': '2415949',
#     'name': '415949 (2001 XY10)',
#     'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2415949',
#     'absolute_magnitude_h': 19.37,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.3552670883,
# ...

# %%
data.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %%
data['near_earth_objects'].keys()
# Out:
# dict_keys(['2024-01-02', '2024-01-01', '2024-01-04', '2024-01-03', '2024-01-06', '2024-01-05', '2024-01-07'])

# %%
data['near_earth_objects']['2024-01-01'][0]
# Out:
# {'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3724393?api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ'},
#  'id': '3724393',
#  'neo_reference_id': '3724393',
#  'name': '(2015 OD22)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3724393',
#  'absolute_magnitude_h': 21.21,
#  'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.152249185,
#    'estimated_diameter_max': 0.3404395273},
#   'meters': {'estimated_diameter_min': 152.249185036,
#    'estimated_diameter_max': 340.4395272595},
#   'miles': {'estimated_diameter_min': 0.0946032284,
#    'estimated_diameter_max': 0.2115392495},
#   'feet': {'estimated_diameter_min': 499.5052162336,
#    'estimated_diameter_max': 1116.9276186141}},
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_data': [{'close_approach_date': '2024-01-01',
#    'close_approach_date_full': '2024-Jan-01 11:58',
#    'epoch_date_close_approach': 1704110280000,
# ...

# %%
from datetime import datetime

# %%
import requests
url=f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2024-01-01&end_date=2024-01-07&api_key=Ewvk5QuFLhIpByHlJ7Laa4jrLwg7qNlA2AfeKSfQ"
asteroids_data=[]
target=10000
while len(asteroids_data) < target:
    response = requests.get(url)
    data = response.json()
    details = data['near_earth_objects']
      
    for date, asteroids in details.items():
        for asteroid in asteroids:
            approach=asteroid['close_approach_data'][0]
            asteroids_data.append(
                dict (
                    id = int(asteroid['id']),
                    neo_reference_id = int(asteroid['neo_reference_id']),
                    name = asteroid['name'],
                    absolute_magnitude_h = float(asteroid['absolute_magnitude_h']),
                    estimated_diameter_min_km = float(asteroid['estimated_diameter']['kilometers']['estimated_diameter_min']),
                    estimated_diameter_max_km = float(asteroid['estimated_diameter']['kilometers']['estimated_diameter_max']),
                    is_potentially_hazardous_asteroid = bool(asteroid['is_potentially_hazardous_asteroid']),
                    close_approach_date = datetime.strptime(approach['close_approach_date'],"%Y-%m-%d").date(),
                    relative_velocity_kmph = float(approach['relative_velocity']['kilometers_per_hour']),
                    astronomical = float(approach['miss_distance']['astronomical']),
                    miss_distance_km = float(approach['miss_distance']['kilometers']),
                    miss_distance_lunar = float(approach['miss_distance']['lunar']),
                    orbiting_body = approach['orbiting_body']

                ))

            if len(asteroids_data) >= target :
                          break

        if len(asteroids_data) >= target :
                        break
    url = data['links']['next']

asteroids_data
# Out:
# [{'id': 2415949,
#   'neo_reference_id': 2415949,
#   'name': '415949 (2001 XY10)',
#   'absolute_magnitude_h': 19.37,
#   'estimated_diameter_min_km': 0.3552670883,
#   'estimated_diameter_max_km': 0.7944013596,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': datetime.date(2024, 1, 2),
#   'relative_velocity_kmph': 57205.8951204341,
#   'astronomical': 0.3372535274,
#   'miss_distance_km': 50452409.349026635,
#   'miss_distance_lunar': 131.1916221586,
#   'orbiting_body': 'Earth'},
#  {'id': 3160747,
#   'neo_reference_id': 3160747,
#   'name': '(2003 SR84)',
#   'absolute_magnitude_h': 26.0,
#   'estimated_diameter_min_km': 0.0167708462,
#   'estimated_diameter_max_km': 0.0375007522,
#   'is_potentially_hazardous_asteroid': False,
#   'close_approach_date': datetime.date(2024, 1, 2),
#   'relative_velocity_kmph': 38589.054833182,
#   'astronomical': 0.1323425924,
#   'miss_distance_km': 19798169.933318187,
#   'miss_distance_lunar': 51.4812684436,
# ...

# %%
len(asteroids_data)
# Out:
# 10000

# %%
type(asteroids_data)
# Out:
# list

# %%
asteroids_data[0]
# Out:
# {'id': 2415949,
#  'neo_reference_id': 2415949,
#  'name': '415949 (2001 XY10)',
#  'absolute_magnitude_h': 19.37,
#  'estimated_diameter_min_km': 0.3552670883,
#  'estimated_diameter_max_km': 0.7944013596,
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_date': datetime.date(2024, 1, 2),
#  'relative_velocity_kmph': 57205.8951204341,
#  'astronomical': 0.3372535274,
#  'miss_distance_km': 50452409.349026635,
#  'miss_distance_lunar': 131.1916221586,
#  'orbiting_body': 'Earth'}

# %%
for key, value in asteroids_data[0].items():
    print(f"{key}: {value} → {type(value).__name__}")
# Out:
# id: 2415949 → int
# neo_reference_id: 2415949 → int
# name: 415949 (2001 XY10) → str
# absolute_magnitude_h: 19.37 → float
# estimated_diameter_min_km: 0.3552670883 → float
# estimated_diameter_max_km: 0.7944013596 → float
# is_potentially_hazardous_asteroid: False → bool
# close_approach_date: 2024-01-02 → date
# relative_velocity_kmph: 57205.8951204341 → float
# astronomical: 0.3372535274 → float
# miss_distance_km: 50452409.349026635 → float
# miss_distance_lunar: 131.1916221586 → float
# orbiting_body: Earth → str

# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
asteroids_data[1]
# Out:
# {'id': 3160747,
#  'neo_reference_id': 3160747,
#  'name': '(2003 SR84)',
#  'absolute_magnitude_h': 26.0,
#  'estimated_diameter_min_km': 0.0167708462,
#  'estimated_diameter_max_km': 0.0375007522,
#  'is_potentially_hazardous_asteroid': False,
#  'close_approach_date': datetime.date(2024, 1, 2),
#  'relative_velocity_kmph': 38589.054833182,
#  'astronomical': 0.1323425924,
#  'miss_distance_km': 19798169.933318187,
#  'miss_distance_lunar': 51.4812684436,
#  'orbiting_body': 'Earth'}

# %%
import mysql.connector
from datetime import date

conn = mysql.connector.connect(
    host='localhost',      
    user='root',    
    password='25Mysql@',
    database='neo' 
)
cursor = conn.cursor()

# %%
cursor.execute("""
    CREATE TABLE IF NOT EXISTS asteroids (
        id INT,
        name VARCHAR(255),
        absolute_magnitude_h FLOAT,
        estimated_diameter_min_km FLOAT,
        estimated_diameter_max_km FLOAT,
        is_potentially_hazardous_asteroid BOOLEAN
    );
""")

# %%
cursor.execute("""
    CREATE TABLE IF NOT EXISTS close_approach (
        neo_reference_id INT,
        close_approach_date DATE,
        relative_velocity_kmph FLOAT,
        astronomical FLOAT,
        miss_distance_km FLOAT,
        miss_distance_lunar FLOAT,
        orbiting_body VARCHAR(50)
    );
""")

# %%
conn.commit()

# %%
for asteroid in asteroids_data:
    try:
        cursor.execute("""
            INSERT INTO asteroids (id, name, absolute_magnitude_h,estimated_diameter_min_km, estimated_diameter_max_km,is_potentially_hazardous_asteroid)
            VALUES (%s, %s, %s, %s, %s, %s)
        """, (
            asteroid['id'],
            asteroid['name'],
            asteroid['absolute_magnitude_h'],
            asteroid['estimated_diameter_min_km'],
            asteroid['estimated_diameter_max_km'],
            asteroid['is_potentially_hazardous_asteroid']
        ))

        cursor.execute("""
            INSERT INTO close_approach (neo_reference_id, close_approach_date, relative_velocity_kmph, astronomical,miss_distance_km, miss_distance_lunar,
            orbiting_body)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
        """, (
            asteroid['neo_reference_id'],
            asteroid['close_approach_date'],
            asteroid['relative_velocity_kmph'],
            asteroid['astronomical'],
            asteroid['miss_distance_km'],
            asteroid['miss_distance_lunar'],
            asteroid['orbiting_body']
        ))

    except Exception as e:
        print(f"Error inserting asteroid {asteroid['id']}: {e}")

conn.commit()
